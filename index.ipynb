# %% [markdown]
# # Removing Trends - Lab
#
# ## Introduction
#
# In this lab, you'll practice your detrending skills!
#
# ## Objectives
#
# You will be able to:
# * Learn how to remove trends and seasonality
# * Use a log transformation to minimize non-stationarity
# * Use rolling means to reduce non-stationarity
# * Use differencing to reduce non-stationarity

# %% [markdown]
# ## Detrending the Airpassenger data

# %%
import pandas as pd
from pandas import Series
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# Import passengers.csv and set it as a time-series object. Plot the TS
ts = pd.read_csv('passengers.csv')
print(ts.info())
ts.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
# Month          144 non-null object
# #Passengers    144 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.3+ KB
# None
#         Month  #Passengers
# 0  1949-01-01          112
# 1  1949-02-01          118
# 2  1949-03-01          132
# 3  1949-04-01          129
# 4  1949-05-01          121

# %%
ts.Month = pd.to_datetime(ts.Month)
ts.set_index('Month', inplace=True)
ts.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
ts.plot(figsize=(15, 8))

# %%
ts.columns = ['Passengers']

# %% [markdown]
# ## Create a stationarity check
#
# At this stage, we can use the code from previous labs to create a function `stationarity_check(ts)` that takes in a time series object and performs stationarity checks including rolling statistics and the Dickey Fuller test.
#
# We want the output of the function to:
# - Plot the original time series along with the rolling mean and rolling standard deviation in one plot
# - Output the results of the Dickey-Fuller test

# %%
# Create a function to check for the stationarity of a given timeseries using rolling stats and DF test
# Collect and package the code from previous lab

def stationarity_check(ts):
    
    #import adfuller
    from statsmodels.tsa.stattools import adfuller
    
    #calculate rolling statistics
    rollmean = ts.rolling(window= 8, center=False).mean()
    rollstd = ts.rolling(window= 8, center=False).std()
    
    #Perform Dickey-Fuller Test:
    dftest = adfuller(ts['Passengers'])
    
    #Plot rolling statistics
    fig = plt.figure(figsize=(15, 8))
    orig = plt.plot(ts, color='blue', label='Original')
    roll = plt.plot(rollmean, color='orange', label='Rolling Average')
    std = plt.plot(rollstd, color='green', label='Rolling std')
    plt.legend(loc='best')
    plt.show(block=False)
    
    #Print Dickey-Fuller results: 
    print('Results of Dickey-Fuller Test: ')
    
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', 
                                             '#Lags Used', 'Number of Ovbervations Used'])
    for key, value in dftest[4].items():
        dfoutput[f'Critical Value {key}'] = value
#     print(dfoutput)
    
    return dfoutput

# %% [markdown]
# Use your newly created function on the airpassenger data set.

# %%
stationarity_check(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   0.815369
# p-value                          0.991880
# #Lags Used                      13.000000
# Number of Ovbervations Used    130.000000
# Critical Value 1%               -3.481682
# Critical Value 5%               -2.884042
# Critical Value 10%              -2.578770
# dtype: float64

# %% [markdown]
# ## Perform a log() and sqrt() transform

# %%
# Log transform timeseries and compare with original to check the effect

ts_log = np.log(ts)
ts_sqrt= np.sqrt(ts)
fig = plt.figure(figsize=(12,6))
plt.plot(ts,  color='blue');
plt.title('Original')
plt.show()
fig = plt.figure(figsize=(12,6))
plt.plot(ts_log, color='blue');
plt.title('Log Transformation')
plt.show()
fig = plt.figure(figsize=(12,6))
plt.plot(ts_sqrt, color='blue')
plt.title('Sqrt Transformation');

# %% [markdown]
# moving forward, let's keep working with the log transformed data before subtracting rolling mean, differencing, etc.

# %% [markdown]
# ## Subtracting the rolling mean

# %% [markdown]
# Create a rolling mean using your log transformed time series, with a time window of 7. Plot the log-transformed time series and the rolling mean together.

# %%
# your code here
log_rollmean = ts_log.rolling(window=7, center=False).mean()

fig = plt.figure(figsize=(15,8))
plt.plot(ts_log, color='blue', label='Log Transform')
plt.plot(log_rollmean, color='orange', label='Log Rolling Mean')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Now, subtract the rolling mean from the time series, look at the 10 first elements of the result and plot the result.

# %%
# Subtract the moving average from the original data and check head for Nans
data_minus_rollmean = ts_log - log_rollmean
data_minus_rollmean.head(10)
# Out:
#             Passengers
# Month
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01         NaN
# 1949-04-01         NaN
# 1949-05-01         NaN
# 1949-06-01         NaN
# 1949-07-01    0.150059
# 1949-08-01    0.110242
# 1949-09-01    0.005404
# 1949-10-01   -0.113317

# %%
# Drop the NaN values from timeseries calculated above
data_minus_rollmean.dropna(axis=0, inplace=True)

# %%
# Plot the result
data_minus_rollmean.plot(figsize=(15,8))

# %% [markdown]
# Finally, use your function `check_stationarity` to see if this series is considered stationary!

# %%
# Your code here
stationarity_check(data_minus_rollmean)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.348027
# p-value                          0.156946
# #Lags Used                      14.000000
# Number of Ovbervations Used    123.000000
# Critical Value 1%               -3.484667
# Critical Value 5%               -2.885340
# Critical Value 10%              -2.579463
# dtype: float64

# %% [markdown]
# ### Based on the visuals and on the Dickey-Fuller test, what do you conclude?

# %% [markdown]
# # Your conclusion here
# Data is not stationary - p-value is greater than .05

# %% [markdown]
# ## Subtracting the weighted rolling mean

# %% [markdown]
# Repeat all the above for the *weighter* rolling mean. Start from the log-transformed data again. Compare the Dickey-Fuller Test results. What do you conclude?

# %%
# Use Pandas ewma() to calculate Weighted Moving Average of ts_log
exp_rollmean = ts_log.ewm(halflife=4).mean()

# Plot the original data with exp weighted average
fig = plt.figure(figsize=(12,7))
orig = plt.plot(ts_log, color='blue',label='Original')
mean = plt.plot(exp_rollmean, color='red', label='Exponentially Weighted Rolling Mean')
plt.legend(loc='best')
plt.title('Exponentially Weighted Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
# Subtract the moving average from the original data and plot
data_minus_exp_rolmean = ts_log - exp_rollmean
data_minus_exp_rolmean.head(15)

fig = plt.figure(figsize=(11,7))
plt.plot(data_minus_exp_rolmean, color='blue',label='Passengers - weighted rolling mean')
plt.legend(loc='best')
plt.title('Passengers while the weighted rolling mean is subtracted')
plt.show(block=False)

# %%
# do a stationarity check
stationarity_check(data_minus_exp_rolmean)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.297250
# p-value                          0.015002
# #Lags Used                      13.000000
# Number of Ovbervations Used    130.000000
# Critical Value 1%               -3.481682
# Critical Value 5%               -2.884042
# Critical Value 10%              -2.578770
# dtype: float64

# %% [markdown]
# ### Based on the visuals and on the Dickey-Fuller test, what do you conclude?

# %% [markdown]
# # Your conclusion here
# This looks to be stationary

# %% [markdown]
# ## Differencing

# %% [markdown]
# Using exponentially weighted moving averages, we seem to have removed the upward trend, but not the seasonality issue. Now use differencing to remove seasonality. Make sure you use the right amount of `periods`. Start from the log-transformed, exponentially weighted rolling mean-subtracted series.
#
# After you differenced the series, run the `stationarity check` again.

# %%
# difference your data and look at the head
data_diff = data_minus_exp_rolmean.diff(periods=12)
data_diff.head(15)
# Out:
#             Passengers
# Month
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01         NaN
# 1949-04-01         NaN
# 1949-05-01         NaN
# 1949-06-01         NaN
# 1949-07-01         NaN
# 1949-08-01         NaN
# 1949-09-01         NaN
# 1949-10-01         NaN
# 1949-11-01         NaN
# 1949-12-01         NaN
# 1950-01-01   -0.063907
# 1950-02-01   -0.001185
# 1950-03-01    0.029307

# %%
# plot your differenced time series
fig = plt.figure(figsize=(11,7))
plt.plot(data_diff, color='blue',label='passengers - rolling mean')
plt.legend(loc='best')
plt.title('Differenced passengers series')
plt.show(block=False)

# %%
# drop nas
data_diff.dropna(inplace=True)

# %%
# perform the stationarity check
stationarity_check(data_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.601666
# p-value                          0.005729
# #Lags Used                      12.000000
# Number of Ovbervations Used    119.000000
# Critical Value 1%               -3.486535
# Critical Value 5%               -2.886151
# Critical Value 10%              -2.579896
# dtype: float64

# %% [markdown]
# ### Your conclusion

# %% [markdown]
# Even though the rolling mean and rolling average lines do seem to be fluctuating, the movements seem to be completely random,
# and the same conclusion holds for the original time series.
# Your time series is now ready for modeling!

# %% [markdown]
# ## Summary
#
# In this lab, you learned how to make time series stationary through using log transforms, rolling means and differencing.
